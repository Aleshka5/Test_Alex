# %% [markdown]
# # Импорт русской версии

# %%
# !git clone -b in_english https://github.com/Aleshka5/Test_Alex
# Out:
# Cloning into 'Test_Alex'...

# %% [markdown]
# # Import enlish version

# %%
# !git clone https://github.com/Aleshka5/Test_Alex

# %% [markdown]
# # Остальной код

# %%
# %cd Test_Alex/
# Out:
# C:\Users\Aleshka5\my_projects\Test_Alex

# %%
# !pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import main
url = 'https://www.ralphlauren.nl/en/men/clothing/hoodies-sweatshirts/10204'
main.scrape_images(url)
# Out:
# Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36
# https://www.ralphlauren.nl/en/men/clothing/hoodies-sweatshirts/10204?sw1=sw-cache-me&webcat=men%7Cclothing%7Cmen-clothing-hoodies-sweatshirts&start=0&sz=32
# Done 32 out of 142.
# Waiting time for the next request: 0.93 min
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:45.0) Gecko/20100101 Firefox/45.0
# https://www.ralphlauren.nl/en/men/clothing/hoodies-sweatshirts/10204?sw1=sw-cache-me&webcat=men%7Cclothing%7Cmen-clothing-hoodies-sweatshirts&start=32&sz=32
# Try again...
# Waiting time for the next request: 1.67 min
# Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.101 Safari/537.36
# https://www.ralphlauren.nl/en/men/clothing/hoodies-sweatshirts/10204?sw1=sw-cache-me&webcat=men%7Cclothing%7Cmen-clothing-hoodies-sweatshirts&start=32&sz=32
# Done 64 out of 142.
# Waiting time for the next request: 0.38 min
# ...
